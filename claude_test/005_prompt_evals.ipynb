# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Provide minimal but comprehensive criteria on how the task should be solved and the solution evaluated"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(
        messages=messages,
        text = "```json"
    )
    text = chat(
        messages=messages,
        stop_sequences=["```"]
    )
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Repond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""
    
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<solution_criteria>
{test_case["solution_criteria"]}
</solution_criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("../input_data/dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# [{'prompt_inputs': {'height': '180 cm', 'weight': '72 kg', 'goal': 'Marathon training - high-endurance athlete requiring 3000+ calories with carbohydrate loading for sustained energy and recovery', 'restrictions': 'None'}, 'solution_criteria': ['Meal plan totals 3000+ calories across all meals', 'Emphasizes carbohydrates (55-65% of total calories) for endurance fuel and recovery', 'Includes 4-5 meals/snacks distributed throughout the day for sustained energy release', 'Provides practical, compact meal descriptions suitable for a single day'], 'task_description': 'Write a compact, concise 1 day meal plan for a single athlete', 'scenario': 'Testing with a high-endurance athlete (marathon runner) requiring 3000+ calories with emphasis on carbohydrate loading and sustained energy release throughout training and recovery'}, {'prompt_inputs': {'height': '180 cm', 'weight': '85 kg', 'goal': 'Build muscle and strength for weightlifting competition', 'restrictions': 'None'}, 'solution_criteria': ['Meal plan totals 2500+ calories with protein distributed across 4+ meals', 'Includes pre-workout and post-workout nutrition timing', 'Compact format presenting all meals in single day view'], 'task_description': 'Write a compact, concise 1 day meal plan for a single athlete', 'scenario': 'Testing with a strength/power athlete (weightlifter) requiring 2500+ calories with emphasis on protein distribution across meals and timing around workout sessions'}, {'prompt_inputs': {'height': '180 cm', 'weight': '75 kg', 'goal': 'Soccer player seeking balanced nutrition for moderate intensity training with afternoon practice, focusing on energy maintenance and quick recovery', 'restrictions': 'None'}, 'solution_criteria': ['Total daily calories between 2000-2200 kcal', 'Balanced macronutrients (carbs 50-55%, protein 15-20%, fats 25-30%)', 'Meals timed strategically around afternoon practice with pre-workout and post-workout nutrition', 'Includes hydration recommendations and at least two quick recovery snacks'], 'task_description': 'Write a compact, concise 1 day meal plan for a single athlete', 'scenario': 'Testing with a sport-specific athlete (soccer player) requiring moderate calories (2000-2200) with balanced macros and meals timed around practice, emphasizing hydration and quick recovery snacks'}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 5
#       1 with open("../input_data/dataset.json", "r") as f:
#       2     dataset = json.load(f)
#       3     print(dataset)
#       4
# ----> 5 results = run_eval(dataset)
#
# Cell In[9], line 7, in run_eval(dataset)
#       3 def run_eval(dataset):
#       4     results = []
#       5
#       6     for test_case in dataset:
# ----> 7         result = run_test_case(test_case)
#       8         results.append(result)
#       9
#      10     average_score = mean([result["score"] for result in results])
#
# Cell In[8], line 2, in run_test_case(test_case)
#       1 def run_test_case(test_case):
# ----> 2     output = run_prompt(test_case)
#       3
#       4     model_grade = grade_by_model(test_case, output)
#       5     model_score = model_grade["score"]
#
# Cell In[5], line 6, in run_prompt(test_case)
#       2
#       3     prompt = f"""
#       4 Please solve the following task:
#       5
# ----> 6 {test_case["task"]}
#       7
#       8 * Repond only with Python, JSON, or a plain Regex
#       9 * Do not add any comments or commentary or explanation
#
# KeyError: 'task'

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_s3_bucket(uri):\n    match = re.match(r's3://([^/]+)', uri)\n    return match.group(1) if match else None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI and extract only the bucket name",
#       "format": "regex",
#       "solution_criteria": "The regex should match S3 URIs in the format 's3://bucket-name/key/path' and extract only the bucket name portion. It should handle bucket names with hyphens and numbers, and work with both s3:// and https://s3.amazonaws.com/ formats."
#     },
#     "score": 7.5,
#     "reasoning": "The solution correctly implements extraction for the basic s3:// URI format but fails to meet the stated requirements of handling both s3:// and https://s3.amazonaws.com/ formats. While it handles hyphens and numbers appropriately, it lacks robustness through input validation and comprehensive format support. The regex pattern itself is sound for its intended scope, but incomplete for production use."
#   },
#   {
#     "output": "\nimport json\nimport base64\nfrom typing import Any, Dict, Tuple\n\ndef extract_from_lambda_event(event: Dict[str, Any]) -> Dict[str, Any]:\n    \"\"\"\n    Extracts request body, query parameters, and HTTP method from AWS Lambda event.\n    \n    Args:\n        event: AWS Lambda event from API Gateway\n        \n    Returns:\n        Dictionary containing 'method', 'query_params', and 'body'\n    \"\"\"\n    http_method = event.get('httpMethod', event.get('requestContext', {}).get('http', {}).get('method'))\n    \n    query_params = event.get('queryStringParameters') or {}\n    \n    body = event.get('body', '')\n    is_base64 = event.get('isBase64Encoded', False)\n    \n    if is_base64 and body:\n        try:\n            body = base64.b64decode(body).decode('utf-8')\n        except Exception:\n            pass\n    \n    if body and isinstance(body, str):\n        try:\n            body = json.loads(body)\n        except json.JSONDecodeError:\n            pass\n    \n    return {\n        'method': http_method,\n        'query_params': query_params,\n        'body': body\n    }\n",
#     "test_case": {
#       "task": "Create a Python function that takes an AWS Lambda event from API Gateway and extracts the request body, query parameters, and HTTP method",
#       "format": "python",
#       "solution_criteria": "The function should parse a standard AWS Lambda proxy integration event, safely handle JSON parsing of the body, extract queryStringParameters and httpMethod fields, and return a dictionary with these three components. It should handle cases where body is null or queryStringParameters is missing."
#     },
#     "score": 8.5,
#     "reasoning": "The solution effectively meets the core requirements by extracting all three components from Lambda events and handling common edge cases like missing fields and base64 encoding. The multi-version API Gateway support demonstrates good defensive design. However, the silent exception handling approach is a significant weakness that violates AWS/Python best practices and makes the function harder to debug in production. The function would benefit from explicit error handling and logging, or at minimum returning error information to the caller. The implementation is functional but lacks production-grade error visibility."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaExecutionRoleArn\": {\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaExecutionRole\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Generate a CloudFormation template JSON object that defines an AWS IAM role with basic Lambda execution permissions",
#       "format": "json",
#       "solution_criteria": "The JSON should define an IAM role with AssumeRolePolicyDocument allowing Lambda service to assume the role, and attach the AWSLambdaBasicExecutionRole managed policy. The structure should be valid CloudFormation with proper Type, Properties, and Version fields."
#     },
#     "score": 9.0,
#     "reasoning": "The solution fully satisfies the core requirements by defining a valid CloudFormation IAM role with correct assume role policy and basic Lambda execution permissions. The template is syntactically correct and follows CloudFormation best practices. Minor improvements could be made by adding optional but recommended properties like RoleName and Description for better operational clarity."
#   }
# ]
