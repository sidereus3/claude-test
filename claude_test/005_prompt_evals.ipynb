# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Provide minimal but comprehensive criteria on how the task should be solved and the solution evaluated"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(
        messages=messages,
        text = "```json"
    )
    text = chat(
        messages=messages,
        stop_sequences=["```"]
    )
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("../input_data/dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Repond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""
    
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<solution_criteria>
{test_case["solution_criteria"]}
</solution_criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("../input_data/dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nfrom typing import Tuple, Optional\n\ndef parse_s3_uri(uri: str) -> Optional[Tuple[str, str]]:\n    pattern = r'^s3://([a-z0-9\\.\\-]+)(?:/(.*))?$'\n    match = re.match(pattern, uri)\n    if match:\n        bucket = match.group(1)\n        key = match.group(2) or ''\n        return (bucket, key)\n    return None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket URI and extract the bucket name and object key from strings like 's3://my-bucket/path/to/object.txt'",
#       "format": "regex",
#       "solution_criteria": "The regex should correctly capture the bucket name (alphanumeric with hyphens) and the object key path. It should handle URIs with and without trailing slashes. Test cases: 's3://my-bucket/folder/file.txt' should extract 'my-bucket' and 'folder/file.txt'; 's3://data-bucket-123/' should extract 'data-bucket-123' and empty or root path."
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly parses the basic S3 URI format and handles the primary test cases mentioned in the criteria. However, it has notable limitations: the regex pattern is overly restrictive for bucket names (rejecting uppercase, which while not recommended, are technically allowed by AWS), and it doesn't validate important AWS bucket naming constraints. The implementation would benefit from either a more comprehensive regex or additional validation logic to ensure bucket names comply with AWS rules. For typical use cases with lowercase bucket names, this works fine, but it lacks robustness for production code."
#   },
#   {
#     "output": "\nimport json\nfrom typing import Tuple\n\ndef extract_cloudwatch_log_event(event: dict) -> Tuple[int, str]:\n    \"\"\"\n    Extracts timestamp and message from an AWS CloudWatch log event.\n    \n    Args:\n        event: A CloudWatch log event dictionary\n        \n    Returns:\n        A tuple of (timestamp, message)\n    \"\"\"\n    timestamp = event.get('timestamp')\n    message = event.get('message')\n    return (timestamp, message)\n\n\ndef extract_from_cloudwatch_logs(logs_data: dict) -> list[Tuple[int, str]]:\n    \"\"\"\n    Extracts timestamp and message from CloudWatch Logs data structure.\n    \n    Args:\n        logs_data: CloudWatch Logs event data with logEvents\n        \n    Returns:\n        List of tuples containing (timestamp, message) pairs\n    \"\"\"\n    results = []\n    if 'awslogs' in logs_data:\n        payload = json.loads(logs_data['awslogs']['data'])\n        for log_event in payload.get('logEvents', []):\n            timestamp = log_event.get('timestamp')\n            message = log_event.get('message')\n            results.append((timestamp, message))\n    else:\n        for log_event in logs_data.get('logEvents', []):\n            timestamp = log_event.get('timestamp')\n            message = log_event.get('message')\n            results.append((timestamp, message))\n    return results\n",
#     "test_case": {
#       "task": "Create a Python function that takes an AWS CloudWatch log event and extracts the timestamp and message fields, returning them as a tuple",
#       "format": "python",
#       "solution_criteria": "The function should accept a dictionary representing a CloudWatch log event (with 'timestamp' and 'message' keys), extract both values, and return a tuple (timestamp, message). It should handle cases where fields might be missing by raising a KeyError or returning None. The function should be concise (under 5 lines)."
#     },
#     "score": 8.0,
#     "reasoning": "The solution is functional and well-structured, but doesn't strictly adhere to requirements. The primary function is technically correct but violates the conciseness constraint. The inclusion of a second helper function demonstrates good AWS knowledge but extends beyond the original single-function requirement. The graceful None-handling approach is reasonable but doesn't match the criteria's mention of raising KeyError as an option. The main function works correctly for its intended purpose but needs trimming to meet specifications."
#   },
#   {
#     "output": "\nimport json\n\npolicy = {\n    \"Version\": \"2012-10-17\",\n    \"Statement\": [\n        {\n            \"Sid\": \"S3ReadOnlyAccess\",\n            \"Effect\": \"Allow\",\n            \"Action\": [\n                \"s3:GetObject\",\n                \"s3:GetObjectVersion\",\n                \"s3:ListBucket\"\n            ],\n            \"Resource\": [\n                \"arn:aws:s3:::BUCKET_NAME\",\n                \"arn:aws:s3:::BUCKET_NAME/*\"\n            ]\n        }\n    ]\n}\n\nprint(json.dumps(policy, indent=2))\n",
#     "test_case": {
#       "task": "Generate a JSON policy document that grants an IAM role read-only access to a specific S3 bucket",
#       "format": "json",
#       "solution_criteria": "The JSON should be a valid IAM policy with an Effect of 'Allow', appropriate Actions for S3 read operations (s3:GetObject, s3:ListBucket), and a Resource specification for a specific bucket ARN. It should follow AWS IAM policy structure with Version, Statement, Principal (or assume role format), and proper ARN formatting."
#     },
#     "score": 3.5,
#     "reasoning": "The solution provides a functionally correct IAM policy document that would grant read-only S3 access. It follows AWS IAM policy structure and includes appropriate actions and resources. However, it lacks clarity on implementation (how to use the placeholder), and the inclusion of GetObjectVersion slightly over-permissions basic read-only scenarios. The policy itself is valid but could be more explicit about being an identity-based policy versus a resource-based policy."
#   }
# ]
