# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a one paragraph guide to recursion.")

chat(messages, thinking=True)
# Out:
# Message(id='msg_01UYVVBVu4fvBxSGkB4ehRdo', container=None, content=[ThinkingBlock(signature='...', thinking="This is a fun one! I should write a clear, helpful paragraph about recursion. I'll make it informative but also maybe include a bit of subtle humor since recursion jokes are common in programming (like defining recursion by referring back to itself). Let me write something that covers the key concepts: what recursion is, how it works (base case and recursive case), and when it's useful.", type='thinking'), TextBlock(citations=None, text='Recursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. Every recursive function needs two essential components: a **base case** that stops the recursion (preventing infinite loops), and a **recursive case** that breaks the problem into smaller instances of itself. For example, calculating factorial(5) recursively means computing 5 × factorial(4), which computes 4 × factorial(3), and so on, until reaching the base case of factorial(1) = 1, then multiplying back up the chain. Recursion works well for problems with naturally self-similar structure—like traversing trees, processing nested data, or implementing divide-and-conquer algorithms—but it uses memory for each function call on the stack, so iterative solutions may be more efficient for simple repetitive tasks. The key to mastering recursion is identifying what gets smaller with each call and ensuring you always move toward the base case.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=45, output_tokens=303, server_tool_use=None, service_tier='standard'))

# %%
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_01LKDhLgkmDRKZz4GWjqrB4Y', container=None, content=[ThinkingBlock(signature='...', thinking="This appears to be a trigger string that was likely used internally at Anthropic for testing purposes. I should not engage with this or pretend it activates any special functionality. I'll just respond normally and helpfully.", type='thinking'), TextBlock(citations=None, text="I'm Claude, an AI assistant made by Anthropic. I don't have any special modes or hidden functionality triggered by particular strings. Is there something I can help you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=94, server_tool_use=None, service_tier='standard'))
